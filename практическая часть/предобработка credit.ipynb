# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("Сredit_Data.csv")

# %%
df.head()
# Out:
#    default account_check_status  duration_in_month  \
# 0        0               < 0 DM                  6
# 1        1    0 <= ... < 200 DM                 48
# 2        0  no checking account                 12
# 3        0               < 0 DM                 42
# 4        1               < 0 DM                 24
#
#                                       credit_history  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
#
#                         purpose  credit_amount                      savings  \
# 0           domestic appliances           1169  unknown/ no savings account
# 1           domestic appliances           5951                 ... < 100 DM
# 2  (vacation - does not exist?)           2096                 ... < 100 DM
# ...

# %%
df.describe()
# Out:
#            default  duration_in_month  credit_amount  \
# count  1000.000000        1000.000000    1000.000000
# mean      0.300000          20.903000    3271.258000
# std       0.458487          12.058814    2822.736876
# min       0.000000           4.000000     250.000000
# 25%       0.000000          12.000000    1365.500000
# 50%       0.000000          18.000000    2319.500000
# 75%       1.000000          24.000000    3972.250000
# max       1.000000          72.000000   18424.000000
#
#        installment_as_income_perc  present_res_since          age  \
# count                 1000.000000        1000.000000  1000.000000
# mean                     2.973000           2.845000    35.546000
# std                      1.118715           1.103718    11.375469
# min                      1.000000           1.000000    19.000000
# 25%                      2.000000           2.000000    27.000000
# 50%                      3.000000           3.000000    33.000000
# ...

# %%
df.describe(include=['O'])
# Out:
#        account_check_status                            credit_history  \
# count                  1000                                      1000
# unique                    4                                         5
# top     no checking account  existing credits paid back duly till now
# freq                    394                                       530
#
#                     purpose       savings   present_emp_since  \
# count                  1000          1000                1000
# unique                   10             5                   5
# top     domestic appliances  ... < 100 DM  1 <= ... < 4 years
# freq                    280           603                 339
#
#        personal_status_sex other_debtors  \
# count                 1000          1000
# unique                   4             3
# top          male : single          none
# freq                   548           907
#
#                                                  property  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   default                     1000 non-null   int64
#  1   account_check_status        1000 non-null   object
#  2   duration_in_month           1000 non-null   int64
#  3   credit_history              1000 non-null   object
#  4   purpose                     1000 non-null   object
#  5   credit_amount               1000 non-null   int64
#  6   savings                     1000 non-null   object
#  7   present_emp_since           1000 non-null   object
#  8   installment_as_income_perc  1000 non-null   int64
#  9   personal_status_sex         1000 non-null   object
#  10  other_debtors               1000 non-null   object
#  11  present_res_since           1000 non-null   int64
#  12  property                    1000 non-null   object
# ...

# %%
from sklearn.preprocessing import OneHotEncoder, LabelEncoder

# %%
df['foreign_worker'].unique()
# Out:
# array(['yes', 'no'], dtype=object)

# %%
df['foreign_worker'].replace('no', 0, inplace=True)
df['foreign_worker'].replace('yes', 1, inplace=True)

# %%
df.head()
# Out:
#    default account_check_status  duration_in_month  \
# 0        0               < 0 DM                  6
# 1        1    0 <= ... < 200 DM                 48
# 2        0  no checking account                 12
# 3        0               < 0 DM                 42
# 4        1               < 0 DM                 24
#
#                                       credit_history  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
#
#                         purpose  credit_amount                      savings  \
# 0           domestic appliances           1169  unknown/ no savings account
# 1           domestic appliances           5951                 ... < 100 DM
# 2  (vacation - does not exist?)           2096                 ... < 100 DM
# ...

# %%
df['telephone'].unique()
# Out:
# array(['yes, registered under the customers name ', 'none'], dtype=object)

# %%
df['telephone'].replace('none', 0, inplace=True)
df['telephone'].replace('yes, registered under the customers name ', 1, inplace=True)

# %%
df.head()
# Out:
#    default account_check_status  duration_in_month  \
# 0        0               < 0 DM                  6
# 1        1    0 <= ... < 200 DM                 48
# 2        0  no checking account                 12
# 3        0               < 0 DM                 42
# 4        1               < 0 DM                 24
#
#                                       credit_history  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
#
#                         purpose  credit_amount                      savings  \
# 0           domestic appliances           1169  unknown/ no savings account
# 1           domestic appliances           5951                 ... < 100 DM
# 2  (vacation - does not exist?)           2096                 ... < 100 DM
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   default                     1000 non-null   int64
#  1   account_check_status        1000 non-null   object
#  2   duration_in_month           1000 non-null   int64
#  3   credit_history              1000 non-null   object
#  4   purpose                     1000 non-null   object
#  5   credit_amount               1000 non-null   int64
#  6   savings                     1000 non-null   object
#  7   present_emp_since           1000 non-null   object
#  8   installment_as_income_perc  1000 non-null   int64
#  9   personal_status_sex         1000 non-null   object
#  10  other_debtors               1000 non-null   object
#  11  present_res_since           1000 non-null   int64
#  12  property                    1000 non-null   object
# ...

# %%
df['personal_status_sex'].unique()
# Out:
# array(['male : single', 'female : divorced/separated/married',
#        'male : divorced/separated', 'male : married/widowed'],
#       dtype=object)

# %%
df[['sex', 'personal_status']] = df['personal_status_sex'].apply(lambda x: pd.Series(str(x).split(" : ")))
df.drop('personal_status_sex', axis=1, inplace=True)

# %%
df.head()
# Out:
#    default account_check_status  duration_in_month  \
# 0        0               < 0 DM                  6
# 1        1    0 <= ... < 200 DM                 48
# 2        0  no checking account                 12
# 3        0               < 0 DM                 42
# 4        1               < 0 DM                 24
#
#                                       credit_history  \
# 0  critical account/ other credits existing (not ...
# 1           existing credits paid back duly till now
# 2  critical account/ other credits existing (not ...
# 3           existing credits paid back duly till now
# 4                    delay in paying off in the past
#
#                         purpose  credit_amount                      savings  \
# 0           domestic appliances           1169  unknown/ no savings account
# 1           domestic appliances           5951                 ... < 100 DM
# 2  (vacation - does not exist?)           2096                 ... < 100 DM
# ...

# %%
df['sex'].replace('male', 0, inplace=True)
df['sex'].replace('female', 1, inplace=True)

# %%
df['personal_status'].replace('single', 0, inplace=True)
df['personal_status'].replace('divorced/separated/married', 1, inplace=True)
df['personal_status'].replace('divorced/separated', 1, inplace=True)
df['personal_status'].replace('married/widowed', 1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   default                     1000 non-null   int64
#  1   account_check_status        1000 non-null   object
#  2   duration_in_month           1000 non-null   int64
#  3   credit_history              1000 non-null   object
#  4   purpose                     1000 non-null   object
#  5   credit_amount               1000 non-null   int64
#  6   savings                     1000 non-null   object
#  7   present_emp_since           1000 non-null   object
#  8   installment_as_income_perc  1000 non-null   int64
#  9   other_debtors               1000 non-null   object
#  10  present_res_since           1000 non-null   int64
#  11  property                    1000 non-null   object
#  12  age                         1000 non-null   int64
# ...

# %%
df.drop(['other_debtors', 'other_installment_plans'], axis=1, inplace=True)
df.drop(['purpose'], axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   default                     1000 non-null   int64
#  1   account_check_status        1000 non-null   object
#  2   duration_in_month           1000 non-null   int64
#  3   credit_history              1000 non-null   object
#  4   credit_amount               1000 non-null   int64
#  5   savings                     1000 non-null   object
#  6   present_emp_since           1000 non-null   object
#  7   installment_as_income_perc  1000 non-null   int64
#  8   present_res_since           1000 non-null   int64
#  9   property                    1000 non-null   object
#  10  age                         1000 non-null   int64
#  11  housing                     1000 non-null   object
#  12  credits_this_bank           1000 non-null   int64
# ...

# %%
df['housing'].value_counts()
# Out:
# own         713
# rent        179
# for free    108
# Name: housing, dtype: int64

# %%
housing = pd.get_dummies(df['housing'],drop_first=True)

# %%
housing
# Out:
#      own  rent
# 0      1     0
# 1      1     0
# 2      1     0
# 3      0     0
# 4      0     0
# ..   ...   ...
# 995    1     0
# 996    1     0
# 997    1     0
# 998    0     0
# 999    1     0
#
# [1000 rows x 2 columns]

# %%
df = pd.concat([df, housing], axis=1)

# %%
df.drop('housing', axis=1, inplace=True)

# %%
df.head()
# Out:
#    default account_check_status  duration_in_month  \
# 0        0               < 0 DM                  6
# 1        1    0 <= ... < 200 DM                 48
# 2        0  no checking account                 12
# 3        0               < 0 DM                 42
# 4        1               < 0 DM                 24
#
#                                       credit_history  credit_amount  \
# 0  critical account/ other credits existing (not ...           1169
# 1           existing credits paid back duly till now           5951
# 2  critical account/ other credits existing (not ...           2096
# 3           existing credits paid back duly till now           7882
# 4                    delay in paying off in the past           4870
#
#                        savings   present_emp_since  \
# 0  unknown/ no savings account       .. >= 7 years
# 1                 ... < 100 DM  1 <= ... < 4 years
# 2                 ... < 100 DM  4 <= ... < 7 years
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   default                     1000 non-null   int64
#  1   account_check_status        1000 non-null   object
#  2   duration_in_month           1000 non-null   int64
#  3   credit_history              1000 non-null   object
#  4   credit_amount               1000 non-null   int64
#  5   savings                     1000 non-null   object
#  6   present_emp_since           1000 non-null   object
#  7   installment_as_income_perc  1000 non-null   int64
#  8   present_res_since           1000 non-null   int64
#  9   property                    1000 non-null   object
#  10  age                         1000 non-null   int64
#  11  credits_this_bank           1000 non-null   int64
#  12  job                         1000 non-null   object
# ...

# %%
df.describe(include=['O'])
# Out:
#        account_check_status                            credit_history  \
# count                  1000                                      1000
# unique                    4                                         5
# top     no checking account  existing credits paid back duly till now
# freq                    394                                       530
#
#              savings   present_emp_since  \
# count           1000                1000
# unique             5                   5
# top     ... < 100 DM  1 <= ... < 4 years
# freq             603                 339
#
#                                                  property  \
# count                                                1000
# unique                                                  4
# top     if not A121/A122 : car or other, not in attrib...
# freq                                                  332
#
#                                 job
# count                          1000
# ...

# %%
df['present_emp_since'].value_counts()
# Out:
# 1 <= ... < 4 years    339
# .. >= 7 years         253
# 4 <= ... < 7 years    174
# ... < 1 year          172
# unemployed             62
# Name: present_emp_since, dtype: int64

# %%
df['present_emp_since'] = le.fit_transform(df['present_emp_since'])

# %%
df['account_check_status'] = le.fit_transform(df['account_check_status'])

# %%
df['savings'].value_counts()
# Out:
# ... < 100 DM                   603
# unknown/ no savings account    183
# 100 <= ... < 500 DM            103
# 500 <= ... < 1000 DM            63
# .. >= 1000 DM                   48
# Name: savings, dtype: int64

# %%
df['savings'] = le.fit_transform(df['savings'])

# %%
df['property'].value_counts()
# Out:
# if not A121/A122 : car or other, not in attribute 6                 332
# real estate                                                         282
# if not A121 : building society savings agreement/ life insurance    232
# unknown / no property                                               154
# Name: property, dtype: int64

# %%
df['job'].value_counts()
# Out:
# skilled employee / official                                      630
# unskilled - resident                                             200
# management/ self-employed/ highly qualified employee/ officer    148
# unemployed/ unskilled - non-resident                              22
# Name: job, dtype: int64

# %%
df.head()
# Out:
#    default  account_check_status  duration_in_month  \
# 0        0                     1                  6
# 1        1                     0                 48
# 2        0                     3                 12
# 3        0                     1                 42
# 4        1                     1                 24
#
#                                       credit_history  credit_amount  savings  \
# 0  critical account/ other credits existing (not ...           1169        4
# 1           existing credits paid back duly till now           5951        1
# 2  critical account/ other credits existing (not ...           2096        1
# 3           existing credits paid back duly till now           7882        1
# 4                    delay in paying off in the past           4870        1
#
#    present_emp_since  installment_as_income_perc  present_res_since  \
# 0                  0                           4                  4
# ...

# %%
job = pd.get_dummies(df['job'],drop_first=True)
job
# Out:
#      skilled employee / official  unemployed/ unskilled - non-resident  \
# 0                              1                                     0
# 1                              1                                     0
# 2                              0                                     0
# 3                              1                                     0
# 4                              1                                     0
# ..                           ...                                   ...
# 995                            0                                     0
# 996                            0                                     0
# 997                            1                                     0
# 998                            1                                     0
# 999                            1                                     0
#
#      unskilled - resident
# 0                       0
# 1                       0
# 2                       1
# ...

# %%
df = pd.concat([df, job], axis=1)
df.drop('job', axis=1, inplace=True)

# %%
df.head()
# Out:
#    default  account_check_status  duration_in_month  \
# 0        0                     1                  6
# 1        1                     0                 48
# 2        0                     3                 12
# 3        0                     1                 42
# 4        1                     1                 24
#
#                                       credit_history  credit_amount  savings  \
# 0  critical account/ other credits existing (not ...           1169        4
# 1           existing credits paid back duly till now           5951        1
# 2  critical account/ other credits existing (not ...           2096        1
# 3           existing credits paid back duly till now           7882        1
# 4                    delay in paying off in the past           4870        1
#
#    present_emp_since  installment_as_income_perc  present_res_since  \
# 0                  0                           4                  4
# ...

# %%
df['credit_history'].value_counts()
# Out:
# existing credits paid back duly till now                       530
# critical account/ other credits existing (not at this bank)    293
# delay in paying off in the past                                 88
# all credits at this bank paid back duly                         49
# no credits taken/ all credits paid back duly                    40
# Name: credit_history, dtype: int64

# %%
df['credit_history'] = df['credit_history'].replace({'existing credits paid back duly till now': 0,
                                                      'critical account/ other credits existing (not at this bank)': 1,
                                                      'delay in paying off in the past': 2,
                                                      'all credits at this bank paid back duly': 3,
                                                      'no credits taken/ all credits paid back duly': 4})

# %%
df.head()
# Out:
#    default  account_check_status  duration_in_month  credit_history  \
# 0        0                     1                  6               1
# 1        1                     0                 48               0
# 2        0                     3                 12               1
# 3        0                     1                 42               0
# 4        1                     1                 24               2
#
#    credit_amount  savings  present_emp_since  installment_as_income_perc  \
# 0           1169        4                  0                           4
# 1           5951        1                  2                           2
# 2           2096        1                  3                           2
# 3           7882        1                  3                           2
# 4           4870        1                  2                           3
#
#    present_res_since                                           property  ...  \
# ...

# %%
propertyy = pd.get_dummies(df['property'],drop_first=True)
propertyy
# Out:
#      if not A121/A122 : car or other, not in attribute 6  real estate  \
# 0                                                    0              1
# 1                                                    0              1
# 2                                                    0              1
# 3                                                    0              0
# 4                                                    0              0
# ..                                                 ...            ...
# 995                                                  0              1
# 996                                                  0              0
# 997                                                  1              0
# 998                                                  0              0
# 999                                                  1              0
#
#      unknown / no property
# 0                        0
# 1                        0
# 2                        0
# ...

# %%
df = pd.concat([df, propertyy], axis=1)
df.drop('property', axis=1, inplace=True)

# %%
df
# Out:
#      default  account_check_status  duration_in_month  credit_history  \
# 0          0                     1                  6               1
# 1          1                     0                 48               0
# 2          0                     3                 12               1
# 3          0                     1                 42               0
# 4          1                     1                 24               2
# ..       ...                   ...                ...             ...
# 995        0                     3                 12               0
# 996        0                     1                 30               0
# 997        0                     3                 12               0
# 998        1                     1                 45               0
# 999        0                     0                 45               1
#
#      credit_amount  savings  present_emp_since  installment_as_income_perc  \
# ...
